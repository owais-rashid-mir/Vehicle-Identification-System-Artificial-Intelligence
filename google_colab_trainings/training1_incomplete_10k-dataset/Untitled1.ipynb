# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
ROOT_DIR = '/content/gdrive/My Drive/datasets'

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 614.2/614.2 kB 9.1 MB/s eta 0:00:00
# ...

# %%
#import os

from ultralytics import YOLO


# Load a model
model = YOLO("yolov8n.yaml")  # build a new model from scratch

# Use the model
results = model.train(data=os.path.join(ROOT_DIR, "data.yaml"), epochs=50)  # train the model

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# %%
# !scp -r /content/runs '/content/gdrive/My Drive/datasets'

# %%
from ultralytics import YOLO

model = YOLO('/content/runs/detect/train9/weights/last.pt')
model.resume = True
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-17-bd2541273c59> in <cell line: 3>()
#       1 from ultralytics import YOLO
#       2
# ----> 3 model = YOLO('/content/runs/detect/train9/weights/last.pt')
#       4 model.resume = True
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/engine/model.py in __init__(self, model, task)
#      90             self._new(model, task)
#      91         else:
# ---> 92             self._load(model, task)
#      93
#      94     def __call__(self, source=None, stream=False, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/engine/model.py in _load(self, weights, task)
#     136         suffix = Path(weights).suffix
#     137         if suffix == '.pt':
# --> 138             self.model, self.ckpt = attempt_load_one_weight(weights)
#     139             self.task = self.model.args['task']
# ...

# %%
model = YOLO("/content/runs/detect/train9/weights/last.pt")
model.train(resume=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-5ea695376e16> in <cell line: 1>()
# ----> 1 model = YOLO("/content/runs/detect/train9/weights/last.pt")
#       2 model.train(resume=True)
#
# NameError: name 'YOLO' is not defined

# %%
# !scp -r /content/runs '/content/gdrive/My Drive/datasets'
# Out:
# cp: cannot stat '/content/runs': No such file or directory
